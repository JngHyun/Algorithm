# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset("anscombe")

# %%
#%matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
plt.plot(dataset_1['x'],dataset_1['y'])
plt.show()

# %% [markdown]
# # 히스토그램

# %%
tips = sns.load_dataset("tips")

# %%
fig=plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'])
axes1.set_title('histogram of total bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('scatter plot of total bill')
axes1.set_xlabel('total bill')
axes1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
boxplot=plt.figure()
axes1 = boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'],tips[tips['sex']=='Male']['tip']],labels=['Female','Male'])
plt.show()

# %%
def recode_sex(sex):
    if sex=='Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(x = tips['total_bill'],
              y = tips['tip'],
              s = tips['size']*10,
              c = tips['sex_color'],
              alpha= 0.5)

# %%
ax = plt.subplot()
ax = sns.distplot(tips['total_bill'])
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = plt.subplot()
ax = sns.distplot(tips['total_bill'],kde=False)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = plt.subplot()
ax = sns.distplot(tips['total_bill'],hist=False)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
ax = plt.subplot()
ax = sns.distplot(tips['total_bill'],rug=True)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
ax=plt.subplot()
ax = sns.countplot('day',data = tips)

# %%
ax = plt.subplot()
ax = sns.regplot(x='total_bill',y='tip',data=tips)

# %%
ax = plt.subplot()
ax = sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)

# %%
joint = sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
joint = sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
joint = sns.kdeplot(x='total_bill',y='tip',data=tips,shade=True)

# %%
sns.barplot(x='time',y='total_bill',data=tips) #평균 알아서 계산
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x='time',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot,rug=True)
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
scatter = sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',fit_reg=False)

# %%
scatter = sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',size='size',markers=['o','x'],fit_reg=False)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j7/ngck093n5flf7k894rrr3ggw0000gn/T/ipykernel_11137/2687564625.py in <module>
# ----> 1 scatter = sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',size='size',markers=['o','x'],fit_reg=False)
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
anscompe_plot= sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False,col='dataset',col_wrap=2)

# %%
facet = sns.FacetGrid(tips,col='time')
facet = facet.map(plt.hist,'total_bill')

# %%
facet = sns.FacetGrid(tips,col='day',hue='sex')
facet = facet.map(plt.scatter,'total_bill','tip')
facet = facet.add_legend()

# %%
facet = sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
facet = facet.map(plt.scatter,'total_bill','tip')

# %%
import pandas as pd
ebola = pd.read_csv('./data/country_timeseries.csv')

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola.shape[0]-ebola.count()
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
import numpy as np
# Out:
# 1214

# %%
ebola.fillna(ebola.mean())
# Out:
# /var/folders/j7/ngck093n5flf7k894rrr3ggw0000gn/T/ipykernel_11137/3851241449.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ebola.fillna(ebola.mean())
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289   2776.000000    2335.337349       10030.000000
# 1      1/4/2015  288   2775.000000    2335.337349        9780.000000
# 2      1/3/2015  287   2769.000000    8166.000000        9722.000000
# 3      1/2/2015  286    911.064516    8157.000000        2427.367816
# 4    12/31/2014  284   2730.000000    8115.000000        9633.000000
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5    103.000000       8.000000           6.000000
# 118   3/26/2014    4     86.000000    2335.337349        2427.367816
# ...

# %%
ebola_long = pd.melt(ebola, id_vars=['Date','Day'])

# %%
status_value = ebola_long.variable.str.split('_')
country_value = ebola_long.variable.str.split('_')

# %%
status_value = status_value.str.get(0)
country_value = country_value.str.get(1)

# %%
ebola_long['status'] = status_value
ebola_long['country'] = country_value

# %%
ebola_long
# Out:
#             Date  Day      variable   value  status country
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases  Guinea
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases  Guinea
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases  Guinea
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases  Guinea
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases  Guinea
# ...          ...  ...           ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths    Mali
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths    Mali
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths    Mali
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths    Mali
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths    Mali
#
# [1952 rows x 6 columns]

# %%
weather = pd.read_csv('./data/weather.csv')
weather.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
weather_melt = pd.melt(weather,id_vars=['id','year','month','element'],var_name='day',value_name='temp')
weather_melt.head()
# Out:
#         id  year  month element day  temp
# 0  MX17004  2010      1    tmax  d1   NaN
# 1  MX17004  2010      1    tmin  d1   NaN
# 2  MX17004  2010      2    tmax  d1   NaN
# 3  MX17004  2010      2    tmin  d1   NaN
# 4  MX17004  2010      3    tmax  d1   NaN

# %%
weather_pivot = weather_melt.pivot_table(index=['id','year','month','day'],columns = 'element',values='temp')
weather_pivot.head()
# Out:
# element                 tmax  tmin
# id      year month day
# MX17004 2010 1     d30  27.8  14.5
#              2     d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4

# %%
tips['sex_str'] = tips['sex'].astype(str)

# %%
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_color     category
# sex_str         object
# dtype: object

# %%
import re

# %%
tele_num = '01026628726'

# %%
m = re.match(pattern='\d\d\d\d\d\d\d\d\d\d',string=tele_num)

# %%
# Out:
# <re.Match object; span=(0, 10), match='0102662872'>

# %%
print(bool(m))
# Out:
# True

# %%
tele_num_spaces = '123 456 789'
m = re.match(pattern='\d{10}',string=tele_num_spaces)

# %%
print(bool(m))
# Out:
# False

# %%
m = re.match(pattern='\d{3}\s?\d{3}\s?\d{3}',string=tele_num_spaces)

# %%
print(bool(m))
# Out:
# True

# %%
print(m.group())
# Out:
# 123 456 789

# %%
tele_num_space_paren_dash = '(123) 456-7890'
m = re.match(pattern='\(?\d{3}\)?\s?\d{3}?-?\d{4}',string=tele_num_space_paren_dash)

# %%
print(m.group())
# Out:
# (123) 456-7890

# %%
tips_10 = sns.load_dataset('tips').sample(10)

# %%
tips_10.loc[np.random.permutation(tips_10.index)[:4],'total_bill']=np.NaN

# %%
def fill_na_mean(x):
    mean = x.mean()
    return x.fillna(mean)

# %%
tips['total_bill'] = tips.groupby('sex').total_bill.transform(fill_na_mean)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color sex_str
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0  Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1    Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1    Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1    Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0  Female
# ..          ...   ...     ...    ...   ...     ...   ...       ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1    Male
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0  Female
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1    Male
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1    Male
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0  Female
#
# [244 rows x 9 columns]

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
tips.groupby('size').filter(lambda x: x['size'].count()>=30)
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color sex_str
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0  Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1    Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1    Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1    Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0  Female
# ..          ...   ...     ...    ...   ...     ...   ...       ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1    Male
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0  Female
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1    Male
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1    Male
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0  Female
#
# [231 rows x 9 columns]

# %%
from datetime import datetime

# %%
now1= datetime.now()

# %%
now1
# Out:
# datetime.datetime(2021, 10, 8, 18, 3, 46, 596590)

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola['Date'] = pd.to_datetime(ebola['Date'])

# %%
print(pd.to_datetime(str(now1).split(' ')[0],format='%Y-%m-%d'))
# Out:
# 2021-10-08 00:00:00

# %%
now1.strftime('%Y-%m-%d')
# Out:
# '2021-10-08'

# %%
now1.strftime('%H-%m-%s')
# Out:
# '18-10-1633683826'

# %%
now1.month
# Out:
# 10

# %%
now1.year
# Out:
# 2021

# %%
ebola['year']=ebola['Date'].dt.year

# %%
ebola
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola['Date'] - ebola['Date'].min()
# Out:
# 0     289 days
# 1     288 days
# 2     287 days
# 3     286 days
# 4     284 days
#         ...
# 117     5 days
# 118     4 days
# 119     3 days
# 120     2 days
# 121     0 days
# Name: Date, Length: 122, dtype: timedelta64[ns]

# %%
banks = pd.read_csv('./data/banklist.csv',parse_dates=[5,6])

# %%
banks['quarter'] = banks['Closing Date'].dt.quarter
banks['year'] = banks['Closing Date'].dt.year

# %%
closing_year = banks.groupby(['year']).size()

# %%
cl = banks.groupby(['year','quarter']).size()
cl.head()
# Out:
# year  quarter
# 2000  4          2
# 2001  1          1
#       2          1
#       3          2
# 2002  1          6
# dtype: int64

# %%
fig = plt.figure(figsize=(16,6))
ax1= fig.add_subplot(1,2,1)
ax1 = cl.plot()
ax2 = fig.add_subplot(1,2,2)
ax2 = closing_year.plot()
fig.tight_layout()

# %%
# !pip install pandas-datareader

# %%
tesla = pd.read_csv('./data/tesla_stock_quandl.csv',parse_dates=[0])

# %%
tesla.loc[(tesla.Date.dt.year==2010)&(tesla.Date.dt.month==6)]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
tesla.index = tesla['Date']

# %%
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# ...

# %%
tesla['2015']
# Out:
# /var/folders/j7/ngck093n5flf7k894rrr3ggw0000gn/T/ipykernel_11137/2920848526.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   tesla['2015']
#                  Date    Open      High       Low    Close     Volume  \
# Date
# 2015-12-31 2015-12-31  238.51  243.4500  238.3700  240.010  2715038.0
# 2015-12-30 2015-12-30  236.60  243.6340  235.6707  238.090  3697921.0
# 2015-12-29 2015-12-29  230.06  237.7200  229.5470  237.190  2406290.0
# 2015-12-28 2015-12-28  231.49  231.9800  225.5400  228.950  1901304.0
# 2015-12-24 2015-12-24  230.56  231.8800  228.2800  230.570   710277.0
# ...               ...     ...       ...       ...      ...        ...
# 2015-01-08 2015-01-08  212.81  213.7999  210.0100  210.615  3442509.0
# 2015-01-07 2015-01-07  213.35  214.7800  209.7800  210.950  2968390.0
# ...

# %%
ebola=pd.read_csv('./data/country_timeseries.csv',parse_dates=['Date'])

# %%
ebola.index = ebola['Date']

# %%
new_idx= pd.date_range(ebola.index.min(), ebola.index.max())

# %%
new_idx = reversed(new_idx)

# %%
new_idx

# %%
ebola.reindex(new_idx)
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
# ...               ...    ...           ...            ...                ...
# 2014-03-26 2014-03-26    4.0          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2.0          86.0            NaN                NaN
# 2014-03-23        NaT    NaN           NaN            NaN                NaN
# 2014-03-22 2014-03-22    0.0          49.0            NaN                NaN
#
# ...

# %%
last_valid = ebola.apply(pd.Series.last_valid_index)

# %%
first_valid = ebola.apply(pd.Series.first_valid_index)

# %%
earliest_date = ebola.index.min()

# %%
shift_values = last_valid - earliest_date

# %%
ebola_dict={}
for idx,col in enumerate(ebola):
    d = shift_values[idx].days
    shifted = ebola[col].shift(d)
    ebola_dict[col]=shifted

# %%
pd.DataFrame(ebola_dict)
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN                NaN
# 2015-01-04 2015-01-04  288        2775.0            NaN                NaN
# 2015-01-03 2015-01-03  287        2769.0            NaN                NaN
# 2015-01-02 2015-01-02  286           NaN            NaN                NaN
# 2014-12-31 2014-12-31  284        2730.0            NaN                NaN
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0           18.0                2.0
# 2014-03-26 2014-03-26    4          86.0            8.0                2.0
# 2014-03-25 2014-03-25    3          86.0            8.0                2.0
# 2014-03-24 2014-03-24    2          86.0            7.0                NaN
# 2014-03-22 2014-03-22    0          49.0            3.0                2.0
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'a':[10,20,30],
                  'b':[20,30,40]})
def avg_2_apply(row):
    x = row[0]
    y = row[1]
    if x==20:
        return np.nan
    else:
        return (x+y)/2

# %%
# %%timeit
df.apply(avg_2_apply,axis=1)
# Out:
# 102 µs ± 486 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
@np.vectorize
def v_avg_2_mod(x,y):
    if (x==20):
        return(np.NaN)
    else:
        return (x+y)/2

# %%
# %%timeit
v_avg_2_mod(df['a'],df['b'])
# Out:
# 12.4 µs ± 18.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import numba
@numba.vectorize
def v_avg_2_numba(x,y):
    if (x==20):
        return(np.NaN)
    else:
        return (x+y)/2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/j7/ngck093n5flf7k894rrr3ggw0000gn/T/ipykernel_11137/2240302129.py in <module>
# ----> 1 import numba
#       2 @numba.vectorize
#       3 def v_avg_2_numba(x,y):
#       4     if (x==20):
#       5         return(np.NaN)
#
# ModuleNotFoundError: No module named 'numba'

# %%
# %%timeit
v_avg_2_mod(df['a'],df['b'])
